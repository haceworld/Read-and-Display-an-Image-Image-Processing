# %% [markdown]
# # Read and display a single image

# %%
#import libraries
import cv2
import matplotlib.pyplot as plt

# %%
#read the image
img = cv2.imread(r'D:\Youtube\data\Car.jpg') #'D:/Youtube/data/Car.jpg'

# %%
#display the image
cv2.imshow('Picture', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)
